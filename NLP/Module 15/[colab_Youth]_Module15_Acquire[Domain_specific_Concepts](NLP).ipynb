# %% [markdown]
# # NLP Lesson Map: NLP Process
#
# <font color=red>Red </font> highlighted is the topic covered for this lesson
#
# 1.	<font color=red>Obtain Text</font>
# > *	<font color=red> From NTLK</font>
# > *	From website
# > *	From CSV
# 2.	Tokens
# > *	Sentence Segmentation
# > *	Tokenization
# > *	Remove stopwords, special characters, numbers
# > *	Converting text to a common case
# > *	Stemming & Lemmatization
# 3.	Numbers
# > *	Create a Dictionary
# > *	Create Document Vectors = Bag of Words = Term Frequency (tf)  = number of times that each word occurs per document
# > *	idf
# > *	tf-idf
# 4.	AI Models
# > * Logistic Regression
# > *	Cosine Similarity
# > *	Neural Network
# 5.	NLP Applications
# > * Classification
# > *	Sentiment Analysis
# > *	Chatbot

# %% [markdown]
# ## What is NLTK?
# The Natural Language Toolkit is a popular open source library for Natural Language Processing. NLTK includes software, data, and documentation, freely downloadable from http://nltk.org/. This notebook is inspired by https://www.nltk.org/book/ch01.html
#
# We will be using NLTK extensively in the NLP series of workshops.
#
# In this notebook, we will explore NLTK's text datasets (called corpora) and text processing capability (a fundamental skill in NLP).
#
# First, let's import NLTK!

# %% [markdown]
# ## 1. Import NLTK
#
# Choose 'd' then 'all'.  After downloading all, please enter 'q' to quit downloader.

# %%
import nltk
# Also include nltk.download() if you can't download the books below (next code block)
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
# ...

# %% [markdown]
# NLTK contains several books we can use for our exercises already! Let's load some texts so that we can practise processing them.

# %% [markdown]
# ## 2. Explore NLTK's dataset

# %% [markdown]
# The NLTK library contains several text data we can use to practise on. Let's load them now!

# %%
from nltk.book import * # from NLTK's book module, load all items
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# If you want to find out the title of the text, simply type out their names as shown below:

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# ### Task 1: Explore what are available in the NLTK books by changing the name of the text above! How many of those books are you aware of?

# %% [markdown]
# ## 3. Searching text
#
# ### 3.1 Words in context

# %% [markdown]
# What are some of the ways you examine what the book is about? You read the synopsis, you see the characters, you flip the book and go to parts you might be interested in.
#
# In NLTK, we can look for texts we are interested in, and NLTK will display them together with some context. This is called [concordance](https://www.merriam-webster.com/dictionary/concordance).
# Let's look out for the word 'monstrous' in Moby Dick:
#
# Have you read [Moby Dick?](https://www.shmoop.com/moby-dick/summary.html)

# %%
text1.concordance("monstrous") # Look for the word "monstrous" in text1 (Moby Dick)
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %% [markdown]
# How is the word "montrous" used in text1 (Moby Dick)?

# %% [markdown]
# ### <font color=red>Task 2: Look for the word monstrous in text2 !</font>

# %%
text2.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# . " Now , Palmer , you shall see a monstrous pretty girl ." He immediately went
# your sister is to marry him . I am monstrous glad of it , for then I shall have
# ou may tell your sister . She is a monstrous lucky girl to get him , upon my ho
# k how you will like them . Lucy is monstrous pretty , and so good humoured and
#  Jennings , " I am sure I shall be monstrous glad of Miss Marianne ' s company
#  usual noisy cheerfulness , " I am monstrous glad to see you -- sorry I could n
# t however , as it turns out , I am monstrous glad there was never any thing in
# so scornfully ! for they say he is monstrous fond of her , as well he may . I s
# possible that she should ." " I am monstrous glad of it . Good gracious ! I hav
# thing of the kind . So then he was monstrous happy , and talked on some time ab
# e very genteel people . He makes a monstrous deal of money , and they keep thei

# %% [markdown]
# How do you think the word 'monstrous' is used in this text?
#
# Compare the words that comes in similar context in `text2`. Do you notice the difference between how "monstrous" is used in `text2` as compared to `text1`? In `text2`, monstrous is used generally positively, as seen with the words that have similar context in `text2` like exceedingly, amazingly.

# %% [markdown]
# Great! With the knowledge you have, you can start exploring your dataset and understanding what your dataset is about.
#
# A concordance permits us to see words in context. For example, we saw that monstrous occurred in contexts such as the < `monstrous` > pictures and a < `monstrous` > size . See above to see what other contexts are there.

# %% [markdown]
# See, you are now understanding more about your dataset, understanding how different authors use certain words and how words are used very differently in different text!

# %% [markdown]
# ### 3.2 Location of text - Dispersion plot
#
# We can also use NLTK to find out the distribution of certain words within the text! This will be displayed in what we call the dispersion plot. The code below displays the dispersion plot for the words of our choice.

# %%
text1.dispersion_plot(["Moby", "Dick", "monstrous", "gone", "life"])

# %% [markdown]
# The stripe represent the instance of the word, while the word offset indicates their position within the dataset. Notice where the whale, Moby Dick, started being showcased close to the 1/3 mark of the book.
#
# ### <font color=red>Task 3: Choose 5 other words and plot its dispersion plot.</font>
# Choose some common words and some words that you think will be rare. What do you learn from the distribution of the words?

# %%
text1.dispersion_plot(['the', 'me', 'my', 'curious', 'few'])

# %% [markdown]
# ## 4. Counting vocabulary

# %% [markdown]
# We can find out the length of the text, including the words and punctuation symbols from the text.

# %%
len(text1)
# Out:
# 260819

# %% [markdown]
# What does the number mean? it means that Moby Dick has 260819 words and punctuation symbols. We also call these "tokens".

# %% [markdown]
# We can also find out how many distinct "tokens" are there in the text. The vocabulary of a text is just the set of tokens that it uses, since in a set, all duplicates are collapsed together.

# %%
set(text1)
# Out:
# {'contradictory',
#  'players',
#  'Knights',
#  'mass',
#  'Fish',
#  'exerted',
#  'Lackaday',
#  'tent',
#  'razor',
#  'unsafe',
#  'hydrophobia',
#  'unmanifested',
#  'Scenes',
#  'salmon',
#  'liar',
#  'waned',
#  'princes',
#  'snapped',
#  'tenderness',
#  'delivery',
#  'hilted',
#  'cow',
#  'fatalistic',
#  'excludes',
#  'maltreated',
#  'diademed',
#  'damn',
#  'projecting',
#  'tissues',
#  'Coast',
#  'emigrant',
#  'unvarying',
#  'former',
#  'jugglers',
#  'Antilles',
#  'Tekel',
#  'Enderbies',
#  'unbroken',
#  'southwards',
#  'Spaniards',
#  'itself',
#  'retain',
#  'stript',
#  'context',
#  'Philippine',
#  'unsurrendered',
#  'villainous',
#  'Milky',
#  'knee',
#  'Excellent',
#  'love',
#  'heterogeneously',
#  '4TH',
#  'owns',
#  'adoption',
#  'Leviathans',
#  'longitude',
#  'J',
#  'stirrings',
#  'arrow',
#  'foregoing',
#  'pilot',
#  'righteous',
#  'invoked',
#  'student',
#  'bounded',
#  'relatives',
#  'wept',
#  'anomalous',
#  'common',
# ...

# %% [markdown]
# What does `set()` do?

# %%
sorted(set(text1))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %% [markdown]
# *What* does "`sorted`" do?

# %% [markdown]
# ### <font color=red>Task 4: What is the number of tokens now?</font>
#
# <font color=red>Hint:</font>  combine the use of `len()` and `set()`

# %%
len(set(text1))
# Out:
# 19317

# %% [markdown]
# Great!
#
# We can also count how often a particular word appears in a text.

# %%
text1.count("Moby")
# Out:
# 84

# %% [markdown]
# ### <font color=red>Task 5: Compute the percentage of the book "Moby Dick" that is taken by the word "Moby"</font>

# %%
moby_count = text1.count('Moby')
book_count = len(text1)

percentage_diff = (moby_count/book_count) * 100 
print(percentage_diff)
# Out:
# 0.032206242643365704

# %% [markdown]
# ###<font color=red>Task 6: Compute the percentage of the book "Moby Dick" that is taken by _a word of your choice_.</font>
# Which word do you think can get you >2 percent percentage?

# %%
# the word holds about 5% of the percentile
the_count = text1.count('the')

percentage_diff = (the_count/book_count) * 100 
print(percentage_diff)
# Out:
# 5.260736372733581

# %% [markdown]
# ## 5. Text as lists of words

# %% [markdown]
# In NLTK, we represent the text as a sequence of words and punctuation which can be represented in a list. Below is the list containing the opening line of Moby Dick. Notice how a list is formed:
# - [  ] bracket
# - 'string'
# - comma-separated

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %% [markdown]
# Because the text can be regarded as a list, we can do the list operations we are familiar with.
#
# ### 5.1 addition operator

# %%
['Call', 'me'] + ['Ishmael', '.']
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %% [markdown]
# ### 5.2 multiplication operator

# %%
['Call', 'me'] * 2
# Out:
# ['Call', 'me', 'Call', 'me']

# %% [markdown]
# ### 5.3 appending

# %%
sent1.append("Some")
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Some']

# %% [markdown]
# ### 5.4 indexing

# %% [markdown]
# You can find the location of a particular word in the text when it first occurs

# %%
text1.index("monstrous")
# Out:
# 899

# %% [markdown]
# You can also use list comprehension to find out the positions of more matches in the list. Look at an [example](https://www.datacamp.com/community/tutorials/python-list-index) below:

# %%
list_numbers = [3, 1, 2, 3, 3, 4, 5, 6, 3, 7, 8, 9, 10]
[i for i, n in enumerate(list_numbers) if n == 3] # List comprehension
# Out:
# [0, 3, 4, 8]

# %% [markdown]
# ### <font color=red>Task 7: List the index of all the instances of 'monstrous' in the text!</font>
#
# <font color=red>Hint:</font>  use just above codes for 'monstrous'

# %%
[i for i, n in enumerate(text1) if n == 'monstrous']
# Out:
# [899, 1176, 9530, 9594, 32717, 96103, 124761, 124777, 165681, 209645]

# %% [markdown]
# You can use the index to also access a group of words

# %%
text1[16715:16735]
# Out:
# ['in',
#  'dreams',
#  '--',
#  'I',
#  'opened',
#  'my',
#  'eyes',
#  ',',
#  'and',
#  'the',
#  'before',
#  'sun',
#  '-',
#  'lit',
#  'room',
#  'was',
#  'now',
#  'wrapped',
#  'in',
#  'outer']

# %% [markdown]
# ###<font color=red>Task 8: Create a variable sent1 that includes only one sentence and the word 'monstrous'</font>
#
# <font color=red>Hint:</font>  refer to Task 7 codes

# %%
text1[890:902]
# Out:
# ['Among',
#  'the',
#  'former',
#  ',',
#  'one',
#  'was',
#  'of',
#  'a',
#  'most',
#  'monstrous',
#  'size',
#  '.']

# %% [markdown]
# ## 6. Simple statistics

# %% [markdown]
# We can also learn more about the text with some statistics!
# Say that you want to find out which words are the most important in this text. How would you start?
# We can start with listing the most common words and their frequency.
#
# ### 6.1 Frequency distribution
# First, we will create a variable including the frequency distribution of the text

# %%
fdist1 = FreqDist(text1)
print(fdist1)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %% [markdown]
# What does the output above mean? look at the previous parts of the notebook to figure it out!
#
# Now we can list the most common words and their frequency. the `most_common()` function will list the token in descending order of frequency.

# %%
fdist1.most_common()
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %% [markdown]
# Putting a number in the bracket provides the top `(x)` tokens.

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %% [markdown]
# ###<font color=red>Task 9: list down the frequency distribution of the top 100 most common words</font>
#
# <font color=red>Hint:</font>  refer to Task 8 codes

# %%
fdist1.most_common(100)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %% [markdown]
# Notice what kind of words are present at the top 50. Do you think that these are very meaningful words? what can we call these [words](https://nlp.stanford.edu/IR-book/html/htmledition/dropping-common-terms-stop-words-1.html)?

# %% [markdown]
# We can also find out the frequency of words that do not occur as often by indexing the most common list

# %%
fdist1.most_common()[-19020:-19000]
# Out:
# [('iron', 85),
#  ('Moby', 84),
#  ('Dick', 84),
#  ('shall', 84),
#  ('Jonah', 84),
#  ('seems', 84),
#  ('itself', 84),
#  ('At', 84),
#  ('stand', 83),
#  ('soul', 83),
#  ('going', 83),
#  ('black', 83),
#  ('perhaps', 82),
#  ('wild', 82),
#  ('indeed', 82),
#  ('sometimes', 81),
#  ('known', 80),
#  ('however', 80),
#  ('days', 80),
#  ('seas', 80)]

# %% [markdown]
# We can also count the number of times a given sample occurred:

# %%
fdist1['whale'] #count of the number of times a given sample occurred
# Out:
# 906

# %% [markdown]
# There's more than one way to calculate the number of word 'whale'. You can also use the .count function in python list. See this [example](https://www.w3schools.com/python/ref_list_count.asp).
#
# ### <font color=red>Task 10: Use the `.count` function to calculate the number of word 'whale'!</font>

# %%
text1.count('whale')
# Out:
# 906

# %% [markdown]
# ### 6.1 Plotting distribution graphs
#
# NOW that we can call out the frequency distribution of words in our body of text, let us try to visualize the distribution on the graph! We can use the `.plot` function for this!

# %%
fdist1.plot(50, cumulative=True) 
# cumulative stands for total amount

# %% [markdown]
# What you have plotted is the cumulative graph of the top 50 words.
#
# What does [cumulative](https://dictionary.cambridge.org/dictionary/english/cumulative) mean?
#
# ### <font color=red>Task: plot the graph for the frequency of the top 50 words (not cumulative graph)</font>
#
# <font color=red>Hint:</font>  Refer to previous code

# %%
fdist1.plot(50, cumulative=False)

# %% [markdown]
# How would you describe the graph? What [distribution](https://blog.cloudera.com/wp-content/uploads/2015/12/distribution.png) does this graph looks like? Choose from the image in this [link](https://blog.cloudera.com/wp-content/uploads/2015/12/distribution.png)
#
# How do you think this relates to the tf-idf exercise you've done earlier?

# %% [markdown]
# ## Great job!
#
# In this notebook, you've explored the basic functions of NLTK, the library we will use extensively for NLP.
#
# Remember the text processing activity you have done?
#
# In experience stage, we will use NLTK to to help us with text processing, even bag of words and tf-idf!
